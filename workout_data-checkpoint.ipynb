# %%
import pandas as pd

# %%
workout_data = pd.read_excel(r'C:\Users\sbogu\Documents\DataSets\WorkoutLog\workout_data.xlsx')

# %%
workout_data
# Out:
#     Barbell Bench  Seated Tricep Extension  Seated DB Lateral Raises  \
# 0           175.0                     30.0                      20.0
# 1           165.0                     45.0                      20.0
# 2           165.0                     50.0                      20.0
# 3           185.0                     55.0                      20.0
# 4           185.0                     60.0                      20.0
# 5           185.0                     60.0                      20.0
# 6           195.0                     60.0                      25.0
# 7           205.0                     60.0                      25.0
# 8             NaN                     60.0                      25.0
# 9             NaN                     65.0                      25.0
# 10            NaN                     65.0                      27.5
# 11            NaN                      NaN                      27.5
# 12            NaN                      NaN                      27.5
# ...

# %%
df = workout_data

barbell_bench = df['Barbell Bench'].dropna().unique().tolist()
barbell_bench
# Out:
# [175.0, 165.0, 185.0, 195.0, 205.0]
