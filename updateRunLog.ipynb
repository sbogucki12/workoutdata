# %%
import requests
from datetime import datetime

def format_date(date_str):
    date = datetime.strptime(date_str, "%m/%d/%Y")
    return date.strftime('%Y-%m-%d')

def format_datetime(date_str, time_str):
    date = datetime.strptime(date_str, "%m/%d/%Y")
    time = datetime.strptime(time_str, "%H:%M").time()
    return f"{date.strftime('%Y-%m-%d')}T{time.strftime('%H:%M')}"

# Run details
run_data = {
    "Date": "6/12/2024",
    "Duration": "02:08:43",
    "Length": 17.57,
    "Type": "outdoor",
    "Surface": "street",
    "SleepHours": 7,
    "SleepToBedTime": "22:00",
    "SleepWakeTime": "05:00",
    "RunListenedTo": "none",
    "Temperature": 70,
    "ShoeAge": 5,
    "StartTime": "05:30"
}

# Store the original date string
original_date = run_data["Date"]

# Update the run_data with formatted values
run_data["Date"] = format_date(original_date)
run_data["SleepToBedTime"] = format_datetime(original_date, run_data["SleepToBedTime"])
run_data["SleepWakeTime"] = format_datetime(original_date, run_data["SleepWakeTime"])
run_data["StartTime"] = format_datetime(original_date, run_data["StartTime"])

# API endpoint
url = "https://runlog2021api.azurewebsites.net/api/run/"

# Send POST request
response = requests.post(url, json=run_data)

# Check the response
if response.status_code == 200:
    print("Run log updated successfully!")
else:
    print(f"Failed to update run log. Status code: {response.status_code}")
    print(f"Response: {response.text}")
# Out:
# Failed to update run log. Status code: 201
# Response: {"runId":1535,"date":"2024-06-12T00:00:00","duration":"02:08:43","runKey":null,"imageUrl":null,"length":17.57,"type":"outdoor","surface":"street","pace":"00:07:19.5560615","sleepHours":7,"sleepToBedTime":"2024-06-12T22:00:00","sleepWakeTime":"2024-06-12T05:00:00","runListenedTo":"none","temperature":70,"shoeAge":5,"startTime":"2024-06-12T05:30:00"}

# %%
import requests
from datetime import datetime

def format_date(date_str):
    date = datetime.strptime(date_str, "%m/%d/%Y")
    return date.strftime('%Y-%m-%d')

def format_datetime(date_str, time_str):
    date = datetime.strptime(date_str, "%m/%d/%Y")
    time = datetime.strptime(time_str, "%H:%M").time()
    return f"{date.strftime('%Y-%m-%d')}T{time.strftime('%H:%M')}"

def format_run_data(run):
    formatted_run = run.copy()
    original_date = run["Date"]
    formatted_run["Date"] = format_date(original_date)
    formatted_run["SleepToBedTime"] = format_datetime(original_date, run["SleepToBedTime"])
    formatted_run["SleepWakeTime"] = format_datetime(original_date, run["SleepWakeTime"])
    formatted_run["StartTime"] = format_datetime(original_date, run["StartTime"])
    return formatted_run

# List of run details
runs = [
    {
        "Date": "6/15/2024", "Duration": "02:08:54", "Length": 18.01, "Type": "outdoor",
        "Surface": "street", "SleepHours": 7, "SleepToBedTime": "23:00",
        "SleepWakeTime": "06:00", "RunListenedTo": "none", "Temperature": 63,
        "ShoeAge": 6, "StartTime": "07:00"
    },
    {
        "Date": "6/17/2024", "Duration": "02:02:50", "Length": 17.14, "Type": "outdoor",
        "Surface": "street", "SleepHours": 7, "SleepToBedTime": "22:00",
        "SleepWakeTime": "05:00", "RunListenedTo": "none", "Temperature": 64,
        "ShoeAge": 7, "StartTime": "06:00"
    }
]

# API endpoint
url = "https://runlog2021api.azurewebsites.net/api/run/"

# Process each run
for i, run in enumerate(runs, 1):
    formatted_run = format_run_data(run)
    
    # Send POST request
    response = requests.post(url, json=formatted_run)
    
    # Check the response
    if response.status_code == 200:
        print(f"Run {i} logged successfully!")
    else:
        print(f"Failed to log run {i}. Status code: {response.status_code}")
        print(f"Response: {response.text}")

print("All runs processed.")
# Out:
# Failed to log run 1. Status code: 201
# Response: {"runId":1536,"date":"2024-06-15T00:00:00","duration":"02:08:54","runKey":null,"imageUrl":null,"length":18.01,"type":"outdoor","surface":"street","pace":"00:07:09.4280955","sleepHours":7,"sleepToBedTime":"2024-06-15T23:00:00","sleepWakeTime":"2024-06-15T06:00:00","runListenedTo":"none","temperature":63,"shoeAge":6,"startTime":"2024-06-15T07:00:00"}
# Failed to log run 2. Status code: 201
# Response: {"runId":1537,"date":"2024-06-17T00:00:00","duration":"02:02:50","runKey":null,"imageUrl":null,"length":17.14,"type":"outdoor","surface":"street","pace":"00:07:09.9883314","sleepHours":7,"sleepToBedTime":"2024-06-17T22:00:00","sleepWakeTime":"2024-06-17T05:00:00","runListenedTo":"none","temperature":64,"shoeAge":7,"startTime":"2024-06-17T06:00:00"}
# All runs processed.

# %%
import requests
from datetime import datetime

def format_date(date_str):
    date = datetime.strptime(date_str, "%m/%d/%Y")
    return date.strftime('%Y-%m-%d')

def format_datetime(date_str, time_str):
    date = datetime.strptime(date_str, "%m/%d/%Y")
    time = datetime.strptime(time_str, "%H:%M").time()
    return f"{date.strftime('%Y-%m-%d')}T{time.strftime('%H:%M')}"

def format_run_data(run):
    formatted_run = run.copy()
    original_date = run["Date"]
    formatted_run["Date"] = format_date(original_date)
    formatted_run["SleepToBedTime"] = format_datetime(original_date, run["SleepToBedTime"])
    formatted_run["SleepWakeTime"] = format_datetime(original_date, run["SleepWakeTime"])
    formatted_run["StartTime"] = format_datetime(original_date, run["StartTime"])
    return formatted_run

# List of run details
runs = [
    {
        "Date": "6/19/2024", "Duration": "02:00:56", "Length": 17.01, "Type": "outdoor",
        "Surface": "street", "SleepHours": 7, "SleepToBedTime": "23:00",
        "SleepWakeTime": "06:00", "RunListenedTo": "none", "Temperature": 64,
        "ShoeAge": 7, "StartTime": "09:00"
    },
    {
        "Date": "6/22/2024", "Duration": "02:34:21", "Length": 13.66, "Type": "outdoor",
        "Surface": "street", "SleepHours": 7, "SleepToBedTime": "22:00",
        "SleepWakeTime": "05:00", "RunListenedTo": "none", "Temperature": 64,
        "ShoeAge": 8, "StartTime": "07:00"
    },
    {
        "Date": "6/26/2024", "Duration": "01:55:51", "Length": 16.08, "Type": "outdoor",
        "Surface": "street", "SleepHours": 7, "SleepToBedTime": "22:00",
        "SleepWakeTime": "05:00", "RunListenedTo": "none", "Temperature": 77,
        "ShoeAge": 9, "StartTime": "15:30"
    },
    {
        "Date": "6/28/2024", "Duration": "01:55:57", "Length": 16.01, "Type": "outdoor",
        "Surface": "street", "SleepHours": 7, "SleepToBedTime": "22:00",
        "SleepWakeTime": "05:00", "RunListenedTo": "none", "Temperature": 77,
        "ShoeAge": 10, "StartTime": "15:00"
    },
    {
        "Date": "7/1/2024", "Duration": "02:01:37", "Length": 17.01, "Type": "outdoor",
        "Surface": "street", "SleepHours": 7, "SleepToBedTime": "22:00",
        "SleepWakeTime": "05:00", "RunListenedTo": "none", "Temperature": 72,
        "ShoeAge": 11, "StartTime": "09:00"
    },
    {
        "Date": "7/4/2024", "Duration": "02:02:04", "Length": 17.14, "Type": "outdoor",
        "Surface": "street", "SleepHours": 7, "SleepToBedTime": "22:00",
        "SleepWakeTime": "05:00", "RunListenedTo": "none", "Temperature": 70,
        "ShoeAge": 12, "StartTime": "09:30"
    },
    {
        "Date": "7/10/2024", "Duration": "01:36:06", "Length": 13.01, "Type": "outdoor",
        "Surface": "street", "SleepHours": 7, "SleepToBedTime": "22:00",
        "SleepWakeTime": "05:00", "RunListenedTo": "none", "Temperature": 77,
        "ShoeAge": 13, "StartTime": "15:45"
    },
    {
        "Date": "7/12/2024", "Duration": "00:50:07", "Length": 7.34, "Type": "indoor",
        "Surface": "treadmill", "SleepHours": 7, "SleepToBedTime": "22:00",
        "SleepWakeTime": "05:00", "RunListenedTo": "none", "Temperature": 72,
        "ShoeAge": 14, "StartTime": "07:00"
    },
    {
        "Date": "7/13/2024", "Duration": "00:49:51", "Length": 7.40, "Type": "indoor",
        "Surface": "treadmill", "SleepHours": 7, "SleepToBedTime": "22:00",
        "SleepWakeTime": "05:00", "RunListenedTo": "none", "Temperature": 72,
        "ShoeAge": 15, "StartTime": "08:30"
    },
    {
        "Date": "7/13/2024", "Duration": "02:11:14", "Length": 17.01, "Type": "outdoor",
        "Surface": "street", "SleepHours": 7, "SleepToBedTime": "22:00",
        "SleepWakeTime": "05:00", "RunListenedTo": "none", "Temperature": 79,
        "ShoeAge": 16, "StartTime": "15:30"
    }
]

# API endpoint
url = "https://runlog2021api.azurewebsites.net/api/run/"

# Process each run
for i, run in enumerate(runs, 1):
    formatted_run = format_run_data(run)
    
    # Send POST request
    response = requests.post(url, json=formatted_run)
    
    # Check the response
    if response.status_code == 200:
        print(f"Run {i} logged successfully!")
    else:
        print(f"Failed to log run {i}. Status code: {response.status_code}")
        print(f"Response: {response.text}")

print("All runs processed.")
# Out:
# Failed to log run 1. Status code: 201
# Response: {"runId":1538,"date":"2024-06-19T00:00:00","duration":"02:00:56","runKey":null,"imageUrl":null,"length":17.01,"type":"outdoor","surface":"street","pace":"00:07:06.5726044","sleepHours":7,"sleepToBedTime":"2024-06-19T23:00:00","sleepWakeTime":"2024-06-19T06:00:00","runListenedTo":"none","temperature":64,"shoeAge":7,"startTime":"2024-06-19T09:00:00"}
# Failed to log run 2. Status code: 201
# Response: {"runId":1539,"date":"2024-06-22T00:00:00","duration":"02:34:21","runKey":null,"imageUrl":null,"length":13.66,"type":"outdoor","surface":"street","pace":"00:11:17.9648609","sleepHours":7,"sleepToBedTime":"2024-06-22T22:00:00","sleepWakeTime":"2024-06-22T05:00:00","runListenedTo":"none","temperature":64,"shoeAge":8,"startTime":"2024-06-22T07:00:00"}
# Failed to log run 3. Status code: 201
# ...

# %%
import requests
from datetime import datetime

def format_date(date_str):
    date = datetime.strptime(date_str, "%m/%d/%Y")
    return date.strftime('%Y-%m-%d')

def format_datetime(date_str, time_str):
    date = datetime.strptime(date_str, "%m/%d/%Y")
    time = datetime.strptime(time_str, "%H:%M").time()
    return f"{date.strftime('%Y-%m-%d')}T{time.strftime('%H:%M')}"

# Run details
run_data = {
    "Date": "7/16/2024",
    "Duration": "02:11:14",
    "Length": 17.01,
    "Type": "outdoor",
    "Surface": "street",
    "SleepHours": 7,
    "SleepToBedTime": "22:00",
    "SleepWakeTime": "05:00",
    "RunListenedTo": "none",
    "Temperature": 79,
    "ShoeAge": 16,
    "StartTime": "15:30"
}

# Store the original date string
original_date = run_data["Date"]

# Update the run_data with formatted values
run_data["Date"] = format_date(original_date)
run_data["SleepToBedTime"] = format_datetime(original_date, run_data["SleepToBedTime"])
run_data["SleepWakeTime"] = format_datetime(original_date, run_data["SleepWakeTime"])
run_data["StartTime"] = format_datetime(original_date, run_data["StartTime"])

# API endpoint
url = "https://runlog2021api.azurewebsites.net/api/run/"

# Send POST request
response = requests.post(url, json=run_data)

# Check the response
if response.status_code == 200:
    print("Run log updated successfully!")
else:
    print(f"Failed to update run log. Status code: {response.status_code}")
    print(f"Response: {response.text}")
# Out:
# Failed to update run log. Status code: 201
# Response: {"runId":1548,"date":"2024-07-16T00:00:00","duration":"02:11:14","runKey":null,"imageUrl":null,"length":17.01,"type":"outdoor","surface":"street","pace":"00:07:42.9041740","sleepHours":7,"sleepToBedTime":"2024-07-16T22:00:00","sleepWakeTime":"2024-07-16T05:00:00","runListenedTo":"none","temperature":79,"shoeAge":16,"startTime":"2024-07-16T15:30:00"}
